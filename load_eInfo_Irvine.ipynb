# %%
import os
import sys
import numpy as np
import pandas as pd

# %%
# Load electrode locations
SBJ = 'IR21'
xls_file = '/home/knight/ecog/DATA_FOLDER/Irvine/{0}/Notes/{0}_02082016.xlsx'.format(SBJ)
print xls_file
eloc = pd.read_excel(xls_file, sheetname=0, header=0, index_col=0, parse_cols=[0,2,3])
print eloc.index.shape
# Out:
# /home/knight/ecog/DATA_FOLDER/Irvine/IR21/Notes/IR21_02082016.xlsx
# (78,)

# %%
eloc
# Out:
#         status      (second attempt) 02082016
# contact
# LAH1       NaN       Anterior Temporal Cortex
# LAH2       NaN                             wm
# LAH3       NaN               Lateral Amygdala
# LAH4       NaN               Lateral Amygdala
# LAH5       NaN              Hippocampus (CA1)
# LAH6       NaN              Hippocampus (CA1)
# LAH7       NaN              Hippocampus (CA1)
# LAH8       NaN              Hippocampus (CA1)
# LAH9       NaN              Hippocampus (CA1)
# LAH10      NaN              Hippocampus (CA1)
# LAH11      NaN         Hippocampus (CA1) / wm
# LAH12      NaN                             wm
# LAH13      NaN                             wm
# LAH14      ref                             wm
# LAH15      ref                             wm
# LAH16      NaN                             wm
# RAH1       NaN       Anterior Temporal Cortex
# RAH2       NaN              Anterior Amygdala
# RAH3       NaN              Inferior Amygdala
# ...
